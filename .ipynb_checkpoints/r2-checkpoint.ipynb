# %%
# !pip install boto3 --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: boto3 in /usr/lib/python3/dist-packages (1.37.9)
# Requirement already satisfied: botocore<1.38.0,>=1.37.9 in /usr/lib/python3/dist-packages (from boto3) (1.37.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/lib/python3/dist-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/lib/python3/dist-packages (from boto3) (0.11.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/lib/python3/dist-packages (from botocore<1.38.0,>=1.37.9->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/lib/python3/dist-packages (from botocore<1.38.0,>=1.37.9->boto3) (2.3.0)

# %%
# %pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.43.56-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.44.0,>=1.43.56 (from boto3)
#   Downloading botocore-1.43.56-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.20.0,>=0.19.0 (from boto3)
#   Downloading s3transfer-0.19.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from botocore<1.44.0,>=1.43.56->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from botocore<1.44.0,>=1.43.56->boto3) (2.6.3)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.56->boto3) (1.17.0)
# Downloading boto3-1.43.56-py3-none-any.whl (140 kB)
# Downloading botocore-1.43.56-py3-none-any.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 145.9 MB/s  0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.19.2-py3-none-any.whl (90 kB)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [boto3]32m3/4 [boto3]re]
# Successfully installed boto3-1.43.56 botocore-1.43.56 jmespath-1.1.0 s3transfer-0.19.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: /home/ubuntu/jupyter_env/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install s3fs
# Out:
# Collecting s3fs
#   Using cached s3fs-2026.6.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiobotocore<4.0.0,>=2.19.0 (from s3fs)
#   Using cached aiobotocore-3.8.0-py3-none-any.whl.metadata (29 kB)
# Collecting fsspec<2026.6.1,>=2026.6.0 (from s3fs)
#   Downloading fsspec-2026.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from s3fs) (3.14.2)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Using cached aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting botocore<1.43.47,>=1.43.3 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Using cached botocore-1.43.46-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.1.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (6.7.1)
# Collecting wrapt<3.0.0,>=1.10.10 (from aiobotocore<4.0.0,>=2.19.0->s3fs)
#   Using cached wrapt-2.2.2-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.24.5)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from botocore<1.43.47,>=1.43.3->aiobotocore<4.0.0,>=2.19.0->s3fs) (2.6.3)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<4.0.0,>=2.19.0->s3fs) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /home/ubuntu/jupyter_env/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (3.11)
# Using cached s3fs-2026.6.0-py3-none-any.whl (32 kB)
# Using cached aiobotocore-3.8.0-py3-none-any.whl (91 kB)
# Using cached aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Using cached botocore-1.43.46-py3-none-any.whl (15.4 MB)
# Downloading fsspec-2026.6.0-py3-none-any.whl (203 kB)
# Using cached wrapt-2.2.2-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (167 kB)
# Installing collected packages: wrapt, fsspec, aioitertools, botocore, aiobotocore, s3fs
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.12.0
#     Uninstalling fsspec-2025.12.0:
#       Successfully uninstalled fsspec-2025.12.0
#   Attempting uninstall: botocorem━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [fsspec]
#     Found existing installation: botocore 1.43.56━━━━━━━━━━━━━ 1/6 [fsspec]
#     Uninstalling botocore-1.43.56:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [fsspec]
#       Successfully uninstalled botocore-1.43.56━━━━━━━━━━━━━━━━━━━ 3/6 [botocore]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [s3fs]5/6 [s3fs]ore]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.43.56 requires botocore<1.44.0,>=1.43.56, but you have botocore 1.43.46 which is incompatible.
# Successfully installed aiobotocore-3.8.0 aioitertools-0.13.0 botocore-1.43.46 fsspec-2026.6.0 s3fs-2026.6.0 wrapt-2.2.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: /home/ubuntu/jupyter_env/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install s3fs --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: s3fs in /home/ubuntu/.local/lib/python3.13/site-packages (2026.6.0)
# Requirement already satisfied: aiobotocore<4.0.0,>=2.19.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from s3fs) (3.8.0)
# Requirement already satisfied: fsspec<2026.6.1,>=2026.6.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from s3fs) (2026.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from s3fs) (3.14.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (0.13.0)
# Requirement already satisfied: botocore<1.43.47,>=1.43.3 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.43.46)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/lib/python3/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.9.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/lib/python3/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (6.7.1)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/.local/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.24.5)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/lib/python3/dist-packages (from botocore<1.43.47,>=1.43.3->aiobotocore<4.0.0,>=2.19.0->s3fs) (2.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (3.10)

# %%
import boto3
from botocore.exceptions import ClientError

# =====================================================================
# 1. CONFIGURATION
# =====================================================================
ENDPOINT_URL = "https://ef8eef61229ee8854b4237f6949e50d8.r2.cloudflarestorage.com/truestates-re-analytics"
ACCESS_KEY_ID = "c198c85bd01da0931eae24009fb2100b"
SECRET_ACCESS_KEY = "826187ffaee4742816f65ca4ebe149902db75ac52dbb81606bb34fe8bae4a57c"

BUCKET_NAME = "dubai"
LOCAL_FILE_TO_UPLOAD = r"/home/ubuntu/Dubai/data/raw/project_scorecard.xlsx"
R2_OBJECT_NAME = "folder1/folder2/uploaded_truintel.py"
LOCAL_FILE_TO_DOWNLOAD = r"/home/ubuntu/Dubai/data/raw/project_scorecard.xlsx"

# =====================================================================
# 2. INITIALIZE CLIENT
# =====================================================================
    
# Initialize the client with the current region in the loop
s3_client = boto3.client(
    service_name="s3",
    endpoint_url=ENDPOINT_URL,
    aws_access_key_id=ACCESS_KEY_ID,
    aws_secret_access_key=SECRET_ACCESS_KEY,
    region_name="auto"
)


# =====================================================================
# 3. CREATE A BUCKET
# =====================================================================
def create_r2_bucket(bucket_name):
    try:
        print(f"Creating bucket: {bucket_name}...")
        s3_client.create_bucket(Bucket=bucket_name)
        print(f"Success: Bucket '{bucket_name}' created successfully.")
    except ClientError as e:
        print(f"Error creating bucket: {e}")


# =====================================================================
# 4. ADD / UPLOAD A FILE
# =====================================================================
def upload_file_to_r2(local_path, bucket_name, r2_key):
    try:
        print(f"Uploading '{local_path}' to '{bucket_name}' as '{r2_key}'...")
        s3_client.upload_file(local_path, bucket_name, r2_key)
        print("Success: File uploaded successfully.")
    except FileNotFoundError:
        print(f"Error: The local file '{local_path}' was not found.")
    except ClientError as e:
        print(f"Error uploading file: {e}")

# =====================================================================
# 5. PULL / DOWNLOAD A FILE
# =====================================================================
def download_file_from_r2(bucket_name, r2_key, local_path):
    try:
        print(f"Downloading '{r2_key}' from '{bucket_name}' to '{local_path}'...")
        s3_client.download_file(bucket_name, r2_key, local_path)
        print("Success: File downloaded successfully.")
    except ClientError as e:
        print(f"Error downloading file: {e}")

# %%
# 1. Create the bucket
create_r2_bucket(BUCKET_NAME)

# 2. Upload the file
upload_file_to_r2(LOCAL_FILE_TO_UPLOAD, BUCKET_NAME, R2_OBJECT_NAME)

# 3. Pull the file back down
download_file_from_r2(BUCKET_NAME, R2_OBJECT_NAME, LOCAL_FILE_TO_DOWNLOAD)
# Out:
# Creating bucket: dubai...
# Success: Bucket 'dubai' created successfully.
# Uploading '/home/ubuntu/Dubai/data/raw/project_scorecard.xlsx' to 'dubai' as 'folder1/folder2/uploaded_truintel.py'...
# Success: File uploaded successfully.
# Downloading 'folder1/folder2/uploaded_truintel.py' from 'dubai' to '/home/ubuntu/Dubai/data/raw/project_scorecard.xlsx'...
# Success: File downloaded successfully.

# %% [markdown]
# #https://truestates-re-ai.blobs.truestates.ai/test_bucket1/folder1/folder2/uploaded_truintel.py - this is the public link to the file that was uploaded to R2. You can use this link to access the file directly from a web browser or any HTTP client.This can also be used to verify that the file was uploaded successfully to the R2 bucket. This can also be used as a url to download files as well.

# %%
import os

def upload_directory_to_r2(local_dir, bucket_name, r2_prefix):
    """
    Uploads an entire local directory to an R2 bucket while preserving the folder structure.
    """
    print(f"Scanning local directory: {local_dir}")
    
    for root, dirs, files in os.walk(local_dir):
        for file in files:
            # 1. Get the exact local file path
            local_path = os.path.join(root, file)
            
            # 2. Calculate the relative path (to keep subfolders intact)
            relative_path = os.path.relpath(local_path, local_dir)
            
            # 3. Create the target path inside the R2 bucket
            r2_key = f"{r2_prefix}/{relative_path}".replace("\\", "/")
            
            print(f"Uploading: {file} -> s3://{bucket_name}/{r2_key}")
            
            # 4. Upload the file
            s3_client.upload_file(local_path, bucket_name, r2_key)
            
    print("✅ All raw files uploaded successfully!")

# --- Configuration matching your config.yaml ---
LOCAL_RAW_DIR = r"/home/ubuntu/Dubai/data/raw"
R2_TARGET_PREFIX = "data/raw"
BUCKET = "dubai"

# Run the upload
upload_directory_to_r2(LOCAL_RAW_DIR, BUCKET, R2_TARGET_PREFIX)
# Out:
# Scanning local directory: /home/ubuntu/Dubai/data/raw
# Uploading: projects.parquet -> s3://dubai/data/raw/projects.parquet
# Uploading: units.parquet -> s3://dubai/data/raw/units.parquet
# Uploading: developers.parquet -> s3://dubai/data/raw/developers.parquet
# Uploading: buildings.parquet -> s3://dubai/data/raw/buildings.parquet
# Uploading: Dubai_RE_Classification_DLD.xlsx -> s3://dubai/data/raw/Dubai_RE_Classification_DLD.xlsx
# Uploading: developer_scorecard.xlsx -> s3://dubai/data/raw/developer_scorecard.xlsx
# Uploading: transactions.parquet -> s3://dubai/data/raw/transactions.parquet
# Uploading: project_scorecard.xlsx -> s3://dubai/data/raw/project_scorecard.xlsx
# ✅ All raw files uploaded successfully!

# %%
import random
import os

# 1. Fetch the list of all files uploaded to the 'dubai' bucket
response = s3_client.list_objects_v2(Bucket="dubai", Prefix="data/raw/")

if "Contents" in response and len(response["Contents"]) > 0:
    # 2. Pick a random file key from the bucket
    file_keys = [obj["Key"] for obj in response["Contents"]]
    random_key = random.choice(file_keys)
    
    # 3. Define a local destination path (e.g. into /tmp)
    file_name = os.path.basename(random_key)
    local_dest = f"/tmp/{file_name}"
    
    print(f"🎲 Selected random file from R2: {random_key}")
    print(f"📥 Downloading to: {local_dest} ...")
    
    # 4. Download file from Cloudflare R2
    s3_client.download_file("dubai", random_key, local_dest)
    
    # 5. Verify file exists locally and print size
    file_size_mb = os.path.getsize(local_dest) / (1024 * 1024)
    print(f"✅ Success! File downloaded successfully ({file_size_mb:.2f} MB).")
else:
    print("⚠️ No objects found in bucket 'dubai' under prefix 'data/raw/'")
# Out:
# ⚠️ No objects found in bucket 'dubai' under prefix 'data/raw/'

# %%
import os

+
# Change to any local path you prefer

try:
    print(f"📥 Downloading '{R2_FILE_KEY}' from bucket '{BUCKET_NAME}'...")
    s3_client.download_file(BUCKET_NAME, R2_FILE_KEY, LOCAL_DESTINATION)
    
    file_size_mb = os.path.getsize(LOCAL_DESTINATION) / (1024 * 1024)
    print(f"✅ Download complete! File saved to: {LOCAL_DESTINATION} ({file_size_mb:.2f} MB)")
    
except Exception as e:
    print(f"❌ Failed to download file: {e}")
# Out:
# 📥 Downloading 'data/raw/project_scorecard.xlsx' from bucket 'dubai'...
# ✅ Download complete! File saved to: /tmp/project_scorecard.xlsx (0.18 MB)

# %%
import s3fs

# Initialize the S3 file system (it will automatically grab your credentials)
fs = s3fs.S3FileSystem()

# Define your local folder path and your destination R2 path
local_utils_folder = "data/utils/"  # Change this to wherever your local utils folder is
r2_destination = "s3://dubai/data/utils/"

# Push the entire folder to R2
fs.put(local_utils_folder, r2_destination, recursive=True)

print("✅ Utils folder successfully uploaded to R2!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 11
#       8 r2_destination = "s3://dubai/data/utils/"
#      10 # Push the entire folder to R2
# ---> 11 fs.put(local_utils_folder, r2_destination, recursive=True)
#      13 print("✅ Utils folder successfully uploaded to R2!")
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:597, in AsyncFileSystem._put(self, lpath, rpath, recursive, callback, batch_size, maxdepth, **kwargs)
#     595     lpath = make_path_posix(lpath)
#     596 fs = LocalFileSystem()
# --> 597 lpaths = fs.expand_path(lpath, recursive=recursive, maxdepth=maxdepth)
#     598 if source_is_str and (not recursive or maxdepth is not None):
#     599     # Non-recursive glob does not copy directories
#     600     lpaths = [p for p in lpaths if not (trailing_sep(p) or fs.isdir(p))]
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/spec.py:1194, in AbstractFileSystem.expand_path(self, path, recursive, maxdepth, assume_literal, **kwargs)
#    1191     raise ValueError("maxdepth must be at least 1")
#    1193 if isinstance(path, (str, os.PathLike)):
# -> 1194     out = self.expand_path([path], recursive, maxdepth, **kwargs)
#    1195 else:
#    1196     out = set()
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/spec.py:1229, in AbstractFileSystem.expand_path(self, path, recursive, maxdepth, assume_literal, **kwargs)
#    1227             out.add(p)
#    1228 if not out:
# -> 1229     raise FileNotFoundError(path)
#    1230 return sorted(out)
#
# FileNotFoundError: ['/home/ubuntu/Dubai/truestates-ml-ops/data/utils']

# %%
import s3fs

# Initialize the S3 file system
fs = s3fs.S3FileSystem()

# Use your exact absolute path here:
local_utils_folder = "/home/ubuntu/Dubai/data/utils/"
r2_destination = "s3://dubai/data/utils/"

# Push the entire folder to R2
fs.put(local_utils_folder, r2_destination, recursive=True)

print("✅ Utils folder successfully uploaded to R2!")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[33], line 11
#       8 r2_destination = "s3://dubai/data/utils/"
#      10 # Push the entire folder to R2
# ---> 11 fs.put(local_utils_folder, r2_destination, recursive=True)
#      13 print("✅ Utils folder successfully uploaded to R2!")
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:625, in AsyncFileSystem._put(self, lpath, rpath, recursive, callback, batch_size, maxdepth, **kwargs)
#     622 rdirs = [r for l, r in zip(lpaths, rpaths) if is_dir[l]]
#     623 file_pairs = [(l, r) for l, r in zip(lpaths, rpaths) if not is_dir[l]]
# --> 625 await asyncio.gather(*[self._makedirs(d, exist_ok=True) for d in rdirs])
#     626 batch_size = batch_size or self.batch_size
#     628 coros = []
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:1121, in S3FileSystem._makedirs(self, path, exist_ok)
#    1119 async def _makedirs(self, path, exist_ok=False):
#    1120     try:
# -> 1121         await self._mkdir(path, create_parents=True)
#    1122     except FileExistsError:
#    1123         if exist_ok:
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:1106, in S3FileSystem._mkdir(self, path, acl, create_parents, **kwargs)
#    1102 if region_name:
#    1103     params["CreateBucketConfiguration"] = {
#    1104         "LocationConstraint": region_name
#    1105     }
# -> 1106 await self._call_s3("create_bucket", **params)
#    1107 self.invalidate_cache("")
#    1108 self.invalidate_cache(bucket)
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:464, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     462 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     463 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 464 return await _error_wrapper(
#     465     method, kwargs=additional_kwargs, retries=self.retries
#     466 )
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:215, in _error_wrapper(func, args, kwargs, retries)
#     213         err = e
#     214 err = translate_boto_error(err)
# --> 215 raise err
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:169, in _error_wrapper(func, args, kwargs, retries)
#     166 wait_time = min(1.7**i * 0.1, 15)
#     168 try:
# --> 169     return await func(*args, **kwargs)
#     170 except S3_RETRYABLE_ERRORS as e:
#     171     err = e
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/context.py:36, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      34 if hook:
#      35     await resolve_awaitable(hook())
# ---> 36 return await func(*args, **kwargs)
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/client.py:418, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     414     maybe_compress_request(
#     415         self.meta.config, request_dict, operation_model
#     416     )
#     417     apply_request_checksum(request_dict)
# --> 418     http, parsed_response = await self._make_request(
#     419         operation_model, request_dict, request_context
#     420     )
#     422 await self.meta.events.emit(
#     423     f'after-call.{service_id}.{operation_name}',
#     424     http_response=http,
#    (...)    427     context=request_context,
#     428 )
#     430 if http.status_code >= 300:
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/client.py:444, in AioBaseClient._make_request(self, operation_model, request_dict, request_context)
#     440 async def _make_request(
#     441     self, operation_model, request_dict, request_context
#     442 ):
#     443     try:
# --> 444         return await self._endpoint.make_request(
#     445             operation_model, request_dict
#     446         )
#     447     except Exception as e:
#     448         await self.meta.events.emit(
#     449             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#     450             exception=e,
#     451             context=request_context,
#     452         )
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/endpoint.py:118, in AioEndpoint._send_request(self, request_dict, operation_model)
#     116 context = request_dict['context']
#     117 self._update_retries_context(context, attempts)
# --> 118 request = await self.create_request(request_dict, operation_model)
#     119 success_response, exception = await self._get_response(
#     120     request, operation_model, context
#     121 )
#     122 while await self._needs_retry(
#     123     attempts,
#     124     operation_model,
#    (...)    127     exception,
#     128 ):
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/endpoint.py:106, in AioEndpoint.create_request(self, params, operation_model)
#     104     service_id = operation_model.service_model.service_id.hyphenize()
#     105     event_name = f'request-created.{service_id}.{operation_model.name}'
# --> 106     await self._event_emitter.emit(
#     107         event_name,
#     108         request=request,
#     109         operation_name=operation_model.name,
#     110     )
#     111 prepared_request = self.prepare_request(request)
#     112 return prepared_request
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/hooks.py:68, in AioHierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#      65 logger.debug('Event %s: calling handler %s', event_name, handler)
#      67 # Await the handler if its a coroutine.
# ---> 68 response = await resolve_awaitable(handler(**kwargs))
#      69 responses.append((handler, response))
#      70 if stop_on_response and response is not None:
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/_helpers.py:6, in resolve_awaitable(obj)
#       4 async def resolve_awaitable(obj):
#       5     if inspect.isawaitable(obj):
# ----> 6         return await obj
#       8     return obj
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/signers.py:26, in AioRequestSigner.handler(self, operation_name, request, **kwargs)
#      21 async def handler(self, operation_name=None, request=None, **kwargs):
#      22     # This is typically hooked up to the "request-created" event
#      23     # from a client's event emitter.  When a new request is created
#      24     # this method is invoked to sign the request.
#      25     # Don't call this method directly.
# ---> 26     return await self.sign(operation_name, request)
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/signers.py:92, in AioRequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#      89     else:
#      90         raise e
# ---> 92 auth.add_auth(request)
#
# File ~/jupyter_env/lib/python3.13/site-packages/botocore/auth.py:429, in SigV4Auth.add_auth(self, request)
#     427 def add_auth(self, request):
#     428     if self.credentials is None:
# --> 429         raise NoCredentialsError()
#     430     datetime_now = get_current_datetime()
#     431     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
import s3fs

# Initialize the S3 file system WITH your R2 credentials
fs = s3fs.S3FileSystem(
    key="c198c85bd01da0931eae24009fb2100b",
    secret="826187ffaee4742816f65ca4ebe149902db75ac52dbb81606bb34fe8bae4a57c",
    client_kwargs={
        'endpoint_url': 'https://ef8eef61229ee8854b4237f6949e50d8.r2.cloudflarestorage.com/truestates-re-analytics'
    }
)

# Use your exact absolute path here:
local_utils_folder = "/home/ubuntu/Dubai/data/utils/"
r2_destination = "s3://dubai/data/utils/"

# Push the entire folder to R2
fs.put(local_utils_folder, r2_destination, recursive=True)

print("✅ Utils folder successfully uploaded to R2!")
# Out:
# ---------------------------------------------------------------------------
# AccessDenied                              Traceback (most recent call last)
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:169, in _error_wrapper(func, args, kwargs, retries)
#     168 try:
# --> 169     return await func(*args, **kwargs)
#     170 except S3_RETRYABLE_ERRORS as e:
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/context.py:36, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      35     await resolve_awaitable(hook())
# ---> 36 return await func(*args, **kwargs)
#
# File ~/jupyter_env/lib/python3.13/site-packages/aiobotocore/client.py:436, in AioBaseClient._make_api_call(self, operation_name, api_params)
#     435     error_class = self.exceptions.from_code(error_code)
# --> 436     raise error_class(parsed_response, operation_name)
#     437 else:
#
# AccessDenied: An error occurred (AccessDenied) when calling the CreateBucket operation: Access Denied
#
# The above exception was the direct cause of the following exception:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[34], line 17
#      14 r2_destination = "s3://dubai/data/utils/"
#      16 # Push the entire folder to R2
# ---> 17 fs.put(local_utils_folder, r2_destination, recursive=True)
#      19 print("✅ Utils folder successfully uploaded to R2!")
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#     105     return return_result
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      54     coro = asyncio.wait_for(coro, timeout=timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#      58     result[0] = ex
#
# File ~/jupyter_env/lib/python3.13/site-packages/fsspec/asyn.py:625, in AsyncFileSystem._put(self, lpath, rpath, recursive, callback, batch_size, maxdepth, **kwargs)
#     622 rdirs = [r for l, r in zip(lpaths, rpaths) if is_dir[l]]
#     623 file_pairs = [(l, r) for l, r in zip(lpaths, rpaths) if not is_dir[l]]
# --> 625 await asyncio.gather(*[self._makedirs(d, exist_ok=True) for d in rdirs])
#     626 batch_size = batch_size or self.batch_size
#     628 coros = []
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:1121, in S3FileSystem._makedirs(self, path, exist_ok)
#    1119 async def _makedirs(self, path, exist_ok=False):
#    1120     try:
# -> 1121         await self._mkdir(path, create_parents=True)
#    1122     except FileExistsError:
#    1123         if exist_ok:
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:1106, in S3FileSystem._mkdir(self, path, acl, create_parents, **kwargs)
#    1102 if region_name:
#    1103     params["CreateBucketConfiguration"] = {
#    1104         "LocationConstraint": region_name
#    1105     }
# -> 1106 await self._call_s3("create_bucket", **params)
#    1107 self.invalidate_cache("")
#    1108 self.invalidate_cache(bucket)
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:464, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     462 logger.debug("CALL: %s - %s - %s", method.__name__, akwarglist, kw2)
#     463 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
# --> 464 return await _error_wrapper(
#     465     method, kwargs=additional_kwargs, retries=self.retries
#     466 )
#
# File ~/jupyter_env/lib/python3.13/site-packages/s3fs/core.py:215, in _error_wrapper(func, args, kwargs, retries)
#     213         err = e
#     214 err = translate_boto_error(err)
# --> 215 raise err
#
# PermissionError: Access Denied
